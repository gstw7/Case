# %%
import os
import pandas as pd
from dependencies.auxiliar import aux, remover_duplicatas

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
DATA_RAW_PATH = os.path.join('..','data','raw')
DATA_RAW_NAME = 'questao3_creditcard.csv'
DATA_RAW_NAME_2 = 'questao33_creditcard_clientes.csv'
DATA_INTER_PATH = os.path.join('..','data','interim')
DATA_INTER_RAW_NAME = 'df_raw.csv'
DATA_INTER_RAW2_NAME = 'df_raw2.csv'

# %%
df_raw = pd.read_csv(os.path.join(DATA_RAW_PATH, DATA_RAW_NAME), sep=';')
df_raw2 = pd.read_csv(os.path.join(DATA_RAW_PATH,DATA_RAW_NAME_2), sep=';')

# %%
df_raw.head()
# Out:
#           X1   X2         X3        X4   X5     X6     X7     X8     X9  \
# 0  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4
# 1      20000    2          2         1   24      2      2     -1     -1
# 2     120000    2          2         2   26     -1      2      0      0
# 3      90000    2          2         2   34      0      0      0      0
# 4      50000    2          2         1   37      0      0      0      0
#
#      X10    X11        X12        X13        X14        X15        X16  \
# 0  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5
# 1     -2     -2       3913       3102        689          0          0
# 2      0      2       2682       1725       2682       3272       3455
# 3      0      0      29239      14027      13559      14331      14948
# 4      0      0      46990      48233      49291      28314      28959
#
#          X17       X18       X19       X20       X21       X22       X23  \
# ...

# %%
df_raw.drop([0, 0], inplace = True)
df_raw2.drop([0, 0], inplace = True)

# %%
df_raw.rename(columns={'X1': "credito",
                      'X2': 'genero',
                      'X3': 'educacao',
                      'X4': 'status',
                      'X5': 'idade',
                      'Y': 'pag_prox_fatura'}, inplace=True)

df_raw2.rename(columns={'X1': "credito",
                      'X2': 'genero',
                      'X3': 'educacao',
                      'X4': 'status',
                      'X5': 'idade',
                      'Y': 'pag_prox_fatura'}, inplace=True)
df_raw.head()
# Out:
#   credito genero educacao status idade  X6 X7  X8  X9 X10 X11    X12    X13  \
# 1   20000      2        2      1    24   2  2  -1  -1  -2  -2   3913   3102
# 2  120000      2        2      2    26  -1  2   0   0   0   2   2682   1725
# 3   90000      2        2      2    34   0  0   0   0   0   0  29239  14027
# 4   50000      2        2      1    37   0  0   0   0   0   0  46990  48233
# 5   50000      1        2      1    57  -1  0  -1   0   0   0   8617   5670
#
#      X14    X15    X16    X17   X18    X19    X20   X21   X22   X23  \
# 1    689      0      0      0     0    689      0     0     0     0
# 2   2682   3272   3455   3261     0   1000   1000  1000     0  2000
# 3  13559  14331  14948  15549  1518   1500   1000  1000  1000  5000
# 4  49291  28314  28959  29547  2000   2019   1200  1100  1069  1000
# 5  35835  20940  19146  19131  2000  36681  10000  9000   689   679
#
#   pag_prox_fatura
# 1               1
# 2               1
# 3               0
# 4               0
# ...

# %%
aux(df_raw)
# Out:
#                          colunas    tipo  missing   size  unicos  percentual%
# credito                  credito  object        0  27277      80          0.0
# genero                    genero  object        0  27277       2          0.0
# educacao                educacao  object        0  27277       7          0.0
# status                    status  object        0  27277       4          0.0
# idade                      idade  object        0  27277      56          0.0
# X6                            X6  object        0  27277      11          0.0
# X7                            X7  object        0  27277      11          0.0
# X8                            X8  object        0  27277      11          0.0
# X9                            X9  object        0  27277      11          0.0
# X10                          X10  object        0  27277      10          0.0
# X11                          X11  object        0  27277      10          0.0
# ...

# %%
aux(df_raw2)
# Out:
#            colunas    tipo  missing  size  unicos  percentual%
# credito    credito  object        0  2723      61          0.0
# genero      genero  object        0  2723       2          0.0
# educacao  educacao  object        0  2723       7          0.0
# status      status  object        0  2723       4          0.0
# idade        idade  object        0  2723      46          0.0
# X6              X6  object        0  2723      10          0.0
# X7              X7  object        0  2723       9          0.0
# X8              X8  object        0  2723       9          0.0
# X9              X9  object        0  2723       9          0.0
# X10            X10  object        0  2723       8          0.0
# X11            X11  object        0  2723       8          0.0
# X12            X12  object        0  2723    2426          0.0
# X13            X13  object        0  2723    2386          0.0
# X14            X14  object        0  2723    2320          0.0
# ...

# %%
remover_duplicatas(df_raw)
remover_duplicatas(df_raw2)
# Out:
# Removendo...
# Existem 0 colunas duplicadas e 0 linhas duplicadas
# Colunas duplicadas:
# []
# Removendo...
# Existem 0 colunas duplicadas e 0 linhas duplicadas
# Colunas duplicadas:
# []
# (     credito genero educacao status idade  X6  X7  X8  X9 X10 X11     X12  \
#  1      70000      2        2      2    26   2   0   0   2   2   2   41087
#  2     230000      2        1      2    27  -1  -1  -1  -1  -1  -1   16646
#  3      50000      1        2      2    33   2   0   0   0   0   0   30518
#  4      50000      1        1      2    29   2   2   2   2   2   2   24987
#  5      10000      1        2      1    56   2   2   2   0   0   0    2097
#  ...      ...    ...      ...    ...   ...  ..  ..  ..  ..  ..  ..     ...
#  2719   50000      1        3      2    42   0   0   0   0   0   0   43998
#  2720   20000      1        2      1    44  -2  -2  -2  -2  -2  -2    1822
#  2721  250000      1        1      1    34   0   0   0   0   0   0  279640
# ...

# %%
for column in df_raw.columns:
    # converte coluna para tipo indicado no dicionário
    df_raw[column] = df_raw[column].astype('int64', errors='ignore')

for column in df_raw2.columns:
    # converte coluna para tipo indicado no dicionário
    df_raw[column] = df_raw[column].astype('int64', errors='ignore')

# %%
df_raw.head()
# Out:
#    credito  genero  educacao  status  idade  X6  X7  X8  X9  X10  X11    X12  \
# 1    20000       2         2       1     24   2   2  -1  -1   -2   -2   3913
# 2   120000       2         2       2     26  -1   2   0   0    0    2   2682
# 3    90000       2         2       2     34   0   0   0   0    0    0  29239
# 4    50000       2         2       1     37   0   0   0   0    0    0  46990
# 5    50000       1         2       1     57  -1   0  -1   0    0    0   8617
#
#      X13    X14    X15    X16    X17   X18    X19    X20   X21   X22   X23  \
# 1   3102    689      0      0      0     0    689      0     0     0     0
# 2   1725   2682   3272   3455   3261     0   1000   1000  1000     0  2000
# 3  14027  13559  14331  14948  15549  1518   1500   1000  1000  1000  5000
# 4  48233  49291  28314  28959  29547  2000   2019   1200  1100  1069  1000
# 5   5670  35835  20940  19146  19131  2000  36681  10000  9000   689   679
#
#    pag_prox_fatura
# 1                1
# ...
